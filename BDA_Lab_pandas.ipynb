# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijv256/lab_files/blob/main/BDA_Lab_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/BDA/cafe.csv")

# %%
data.head(10)
# Out:
#    Store ID                              Name   Brand Ownership Type  \
# 0     92040                              Fort  Railey         JointV
# 1     92351       Goregaon East - Oberoi Mall  Railey         JointV
# 2     92413                            Colaba  Railey         JointV
# 3    113991                             Powai  Railey         JointV
# 4    114012  Indira Gandhi Itnl Arpt-T3Gate15  Railey         JointV
# 5    113983  Indira Gandhi Itnl Arpt-T3Gate27  Railey         JointV
# 6    114048         Connaught Place - A Block  Railey         JointV
# 7    114050           Elphinstone Road (West)  Railey         JointV
# 8    116462       Vasant Kunj - Ambience Mall  Railey         JointV
# 9    116465                    Ghatkopar West  Railey         JointV
#
#                                              Address       City State Country  \
# 0  Elphinstone Building, Horniman Circle, Veer Na...     Mumbai    MH      IN
# ...

# %%
data.tail()
# Out:
#     Store ID                                 Name   Brand Ownership Type  \
# 80   1013682                            Sector 16  Railey         JointV
# 81   1008832  Chhatrapati Shivaji International A  Railey         JointV
# 82   1006943                    Greater Kailash 2  Railey         JointV
# 83   1013443                Bandra East - One BKC  Railey         JointV
# 84   1015306                   One Horizon Center  Railey         JointV
#
#                                               Address       City State  \
# 80          Ground Floor, Gardens Galleria, Sector 16      Noida    UP
# 81  T2 Departure SHA, Level P9, Food Court, Andher...     Mumbai    MH
# 82  Ground Floor, M-11, M-Block, Main Mrkt, Greate...  New Delhi    DL
# 83  A wing, Ground Floor, One BKC, G Block,BandraB...     Mumbai    MH
# 84                                   Golf Course Road    Gurgaon    HR
#
#    Country Postal Code   Latitude  Longitude             Launch Date  AFF-Mon  \
# ...

# %%
data["AFF-Mon"].sum()
# Out:
# 26966

# %%
data["AFF-Mon"].min()
# Out:
# 122

# %%
data["AFF-Mon"].max()
# Out:
# 399

# %%
data["AFF-Mon"].count()
# Out:
# 85

# %%
data["AFF-Mon"].mean()
# Out:
# 317.2470588235294

# %%
data["AFF-Mon"].describe()
# Out:
# count     85.000000
# mean     317.247059
# std       49.312151
# min      122.000000
# 25%      287.000000
# 50%      314.000000
# 75%      353.000000
# max      399.000000
# Name: AFF-Mon, dtype: float64

# %%
data.describe()
# Out:
#            Store ID   Latitude  Longitude     AFF-Mon     AFF-Tue    AFF-Wed  \
# count  8.500000e+01  85.000000  85.000000   85.000000   85.000000   85.00000
# mean   8.711734e+05  20.652921  75.529383  317.247059  147.552941  336.80000
# std    3.254030e+05   5.567772   2.478295   49.312151   29.774352   56.27564
# min    9.204000e+04  12.906010  72.811928  122.000000  100.000000   78.00000
# 25%    1.006014e+06  18.519234  72.860535  287.000000  126.000000  303.00000
# 50%    1.006943e+06  19.086382  77.072586  314.000000  143.000000  348.00000
# 75%    1.009882e+06  28.475670  77.251785  353.000000  172.000000  377.00000
# max    1.015306e+06  28.693115  80.264076  399.000000  198.000000  397.00000
#
#           AFF-Thu     AFF-Fri     AFF-Sat     AFF-Sun
# count   85.000000   85.000000   85.000000   85.000000
# mean   359.129412  495.070588  549.317647  397.176471
# std     58.631575   35.595207   32.255015   36.494676
# min    191.000000  352.000000  441.000000  206.000000
# ...

# %%
data.describe(include="all")
# Out:
#             Store ID  Name   Brand Ownership Type  \
# count   8.500000e+01    85      85             85
# unique           NaN    85       1              1
# top              NaN  Fort  Railey         JointV
# freq             NaN     1      85             85
# mean    8.711734e+05   NaN     NaN            NaN
# std     3.254030e+05   NaN     NaN            NaN
# min     9.204000e+04   NaN     NaN            NaN
# 25%     1.006014e+06   NaN     NaN            NaN
# 50%     1.006943e+06   NaN     NaN            NaN
# 75%     1.009882e+06   NaN     NaN            NaN
# max     1.015306e+06   NaN     NaN            NaN
#
#                                                   Address    City State  \
# count                                                  85      85    85
# unique                                                 85      10     7
# top     Elphinstone Building, Horniman Circle, Veer Na...  Mumbai    MH
# ...

# %%
data.columns
# Out:
# Index(['Store ID', 'Name', 'Brand', 'Ownership Type', 'Address', 'City',
#        'State', 'Country', 'Postal Code', 'Latitude', 'Longitude',
#        'Launch Date', 'AFF-Mon', 'AFF-Tue', 'AFF-Wed', 'AFF-Thu', 'AFF-Fri',
#        'AFF-Sat', 'AFF-Sun'],
#       dtype='object')

# %%
data["State"].unique()
# Out:
# array(['MH', 'DL', 'HR', 'KA', 'TN', 'AP', 'UP'], dtype=object)

# %%
data["State"].nunique()
# Out:
# 7

# %%
data.shapedata["State"].nunique()
# Out:
# (85, 19)

# %%
x = [i for i in range(85)]
data["New Index"] = x

# %%
data.columns
# Out:
# Index(['Store ID', 'Name', 'Brand', 'Ownership Type', 'Address', 'City',
#        'State', 'Country', 'Postal Code', 'Latitude', 'Longitude',
#        'Launch Date', 'AFF-Mon', 'AFF-Tue', 'AFF-Wed', 'AFF-Thu', 'AFF-Fri',
#        'AFF-Sat', 'AFF-Sun', 'New Index'],
#       dtype='object')

# %%
data.shape
# Out:
# (85, 20)

# %%
data.head()
# Out:
#    Store ID                              Name   Brand Ownership Type  \
# 0     92040                              Fort  Railey         JointV
# 1     92351       Goregaon East - Oberoi Mall  Railey         JointV
# 2     92413                            Colaba  Railey         JointV
# 3    113991                             Powai  Railey         JointV
# 4    114012  Indira Gandhi Itnl Arpt-T3Gate15  Railey         JointV
#
#                                              Address       City State Country  \
# 0  Elphinstone Building, Horniman Circle, Veer Na...     Mumbai    MH      IN
# 1       Off Western Express Highway, Goregaon (East)     Mumbai    MH      IN
# 2  Hotel Taj Mahal Palace, Apollo Bunder, Apollo ...     Mumbai    MH      IN
# 3  Prudential Bldg Hiranandani Bus Park, Gr Fl, C...     Mumbai    MH      IN
# 4  International Departure, Near Gate 15, Terminal 3  New Delhi    DL      IN
#
#   Postal Code   Latitude  Longitude       Launch Date  AFF-Mon  AFF-Tue  \
# ...

# %%
data.drop("New Index", axis=1, inplace=True)

# %%
data.head()
# Out:
#    Store ID                              Name   Brand Ownership Type  \
# 0     92040                              Fort  Railey         JointV
# 1     92351       Goregaon East - Oberoi Mall  Railey         JointV
# 2     92413                            Colaba  Railey         JointV
# 3    113991                             Powai  Railey         JointV
# 4    114012  Indira Gandhi Itnl Arpt-T3Gate15  Railey         JointV
#
#                                              Address       City State Country  \
# 0  Elphinstone Building, Horniman Circle, Veer Na...     Mumbai    MH      IN
# 1       Off Western Express Highway, Goregaon (East)     Mumbai    MH      IN
# 2  Hotel Taj Mahal Palace, Apollo Bunder, Apollo ...     Mumbai    MH      IN
# 3  Prudential Bldg Hiranandani Bus Park, Gr Fl, C...     Mumbai    MH      IN
# 4  International Departure, Near Gate 15, Terminal 3  New Delhi    DL      IN
#
#   Postal Code   Latitude  Longitude       Launch Date  AFF-Mon  AFF-Tue  \
# ...

# %%
data[data["State"]=="TN"]
# Out:
#     Store ID          Name   Brand Ownership Type  \
# 46   1007196     Velachery  Railey         JointV
# 62   1011564    Anna Nagar  Railey         JointV
# 67   1011563    Royapettah  Railey         JointV
# 73   1012363  Numgambakkam  Railey         JointV
# 74   1013162      Alwarpet  Railey         JointV
#
#                                               Address     City State Country  \
# 46  Upper Ground Floor, Phoenix marketcity, Velach...  Chennai    TN      IN
# 62  TBR tower, Y block, 2nd Avenue, Near Ayyappa T...  Chennai    TN      IN
# 67  Ground Floor, Express Avenue Mall, Whites Road...  Chennai    TN      IN
# 73  Ground Floor, Bergamo Mall, Khadar Nawas Khan ...  Chennai    TN      IN
# 74  Ground Floor, MGN Splendor, Off Chamiers Road,...  Chennai    TN      IN
#
#    Postal Code   Latitude  Longitude             Launch Date  AFF-Mon  \
# 46      600042  12.991694  80.217026  07/17/2014 04:00:00 AM      341
# ...

# %%
data.isna()
# Out:
#     Store ID   Name  Brand  Ownership Type  Address   City  State  Country  \
# 0      False  False  False           False    False  False  False    False
# 1      False  False  False           False    False  False  False    False
# 2      False  False  False           False    False  False  False    False
# 3      False  False  False           False    False  False  False    False
# 4      False  False  False           False    False  False  False    False
# ..       ...    ...    ...             ...      ...    ...    ...      ...
# 80     False  False  False           False    False  False  False    False
# 81     False  False  False           False    False  False  False    False
# 82     False  False  False           False    False  False  False    False
# 83     False  False  False           False    False  False  False    False
# 84     False  False  False           False    False  False  False    False
#
# ...

# %%
data["Store ID"].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# Name: Store ID, Length: 85, dtype: bool

# %%
data.isna().sum()
# Out:
# Store ID          0
# Name              0
# Brand             0
# Ownership Type    0
# Address           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Latitude          0
# Longitude         0
# Launch Date       0
# AFF-Mon           0
# AFF-Tue           0
# AFF-Wed           0
# AFF-Thu           0
# AFF-Fri           0
# AFF-Sat           0
# AFF-Sun           0
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
plt.bar(data["City"],data["AFF-Mon"])
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-35740a35f5fc> in <module>
# ----> 1 plt.boxplot(data["City"],data["AFF-Mon"])
#       2 plt.show
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#
# ...
